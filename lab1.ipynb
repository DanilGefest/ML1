# %% [markdown]
# # Лабораторная работа №1

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Напишите программу, которая считывает с клавиатуры последовательно три строки:
# название фильма, название кинотеатра и время, после чего выводит на экран «Билет на "
# [название фильма] " в " [название кинотеатра] " на [время] забронирован.».

# %%
film_name = input('Введите название фильма')
kino_theathre = input('Название кинотеатра')
time = input('время')
print (f'Билет на "{filmName}" в "{kinoTheathre}" на {time} забронирован.')
# Out:
# Билет на "Пиво" в "В пиве" на 12:00 забронирован.

# %% [markdown]
# ## Задание 2

# %% [markdown]
# Напишите программу, которая считывает две строки и выводит «ВЕРНО», если в каждой из
# них записано или слово только да, или только слово нет (в любой комбинации). Если это не
# так, выведите «НЕВЕРНО».

# %%
str1 = input("Введите первую строку")
str2 = input("Введите вторую строку")

if str1 == str2:
    print("ВЕРНО")
else:
    print("НЕВЕРНО")
# Out:
# НЕВЕРНО

# %% [markdown]
# ## Задание 3

# %% [markdown]
# Напишите программу, которая проверяет, что пользователь ввёл корректный логин (не
# содержащий символ «@») и корректный резервный адрес (содержащий символ «@»). Иных
# проверок, кроме указанных здесь, выполнять не надо.
# Используйте оператор in.

# %%
login = input("Введите логин (без @)")
adres = input("Введите резервный адрес (c @)")
if "@" not in login and "@" in adres:
    print (login) 
    print (adres)
else:
    print ("Неверные данные")
# Out:
# Неверные данные

# %% [markdown]
# ## Задание 4

# %% [markdown]
# Напишите программу, которая считывает рост претендентов в отряд космонавтов до тех пор,
# пока не будет введен «!». А затем выводит на первой строчке количество подходящих
# кандидатур, а на второй строке – минимальный и максимальный рост участников,
# отобранных в новый отряд космонавтов. Рост космонавта не может быть больше 190 см и
# меньше 150 см.

# %%
candidates = []
min_height = float('inf')
max_height = float('-inf')
valid_candidates = 0

while True:
    height_input = input("Введите рост претендента (или '!' для завершения): ")
    
    if height_input == '!':
        break
    
    try:
        height = int(height_input)
        if 150 <= height <= 190:
            valid_candidates += 1
            candidates.append(height)
            if height < min_height:
                min_height = height
            if height > max_height:
                max_height = height
    except ValueError:
        print("Ошибка: введите целое число или '!' для завершения.")

print(valid_candidates)
if valid_candidates > 0:
    print(min_height, max_height)
else:
    print("Нет подходящих кандидатов.")
# Out:
# 1
# 178 178

# %% [markdown]
# ## Задание 5

# %% [markdown]
# Напишите программу, которая имитирует проверку пароля, придуманного пользователем.
# Пользователь вводит пару слов: пароль, а потом ещё раз его же, для подтверждения.
# Если введённая пара не удовлетворяет одному из перечисленных ниже условий,
# пользователь вводит пару паролей ещё раз, и так до тех пор, пока не будут выполнены все
# условия (т. е. пока программа не выведет «OK»).
# - если первый пароль из пары, который ввёл пользователь короче 8 символов,
# программа выводит на экран слово "Короткий!" и заново считывает пару слов
# паролей;
# - если же первый пароль из пары достаточно длинный, но в нём содержится сочетание
# символов "123", программа выводит на экран слово "Простой!" и снова читает пару
# слов-паролей;
# - если же предыдущие проверки пройдены успешно, но введённые слова-пароли не
# совпадают, то программа выводит на экран слово "Различаются." и опять же читает
# пару слов-паролей;
# - если же и третья проверка пройдена успешно, программа выводит "OK" (латинскими
# буквами) и заканчивает свою работу.

# %%
def pass_checker():
    password = input("Введите пароль")
    password_repeat = input("Повторите пароль")
    if len(password) <8 or len(password_repeat)< 8:
        print("Короткий!")
    elif "123" in password or "123" in password_repeat:
        print("Простой")
    elif password != password_repeat:
        print("Различаются")
    else:
        print("OK")
        return True
        
    

while True:
    if pass_checker() == True:
        break
# Out:
# Простой
# Короткий!
# Короткий!
# OK

# %% [markdown]
# ## Задание 6

# %% [markdown]
# Выведите пирамиду из символов «*» заданной высоты.

# %%
def print_pyramid(height):
    height = int(height)  # Преобразуем ввод в целое число
    if height == 0:
        print("Высота пирамиды не может быть равна нулю.")
        return
    
    if height > 0:# Прямая пирамида
        for i in range(height):
            spaces = " " * (height - i - 1)
            stars = "*" * (2 * i + 1)
            print(spaces + stars)
    else: # Перевернутая пирамида
        height = abs(height)  
        for i in range(height - 1, -1, -1):  
            spaces = " " * (height - i - 1)
            stars = "*" * (2 * i + 1)
            print(spaces + stars)

height = input("Введите желаемую высоту пирамиды (отрицательное число для перевернутой): ")
print_pyramid(height)
# Out:
#               *
#              ***
#             *****
#            *******
#           *********
#          ***********
#         *************
#        ***************
#       *****************
#      *******************
#     *********************
#    ***********************
#   *************************
#  ***************************
# *****************************

# %% [markdown]
# ## Задание 7

# %% [markdown]
# ## Задание 8

# %% [markdown]
# Условие Дана строка.
# - Сначала выведите третий символ этой строки.
# - Во второй строке выведите предпоследний символ этой строки.
# - В третьей строке выведите первые пять символов этой строки.
# - В четвертой строке выведите всю строку, кроме последних двух символов.
# - В пятой строке выведите все символы с четными индексами (считая, что индексация начинается с 0, поэтому символы выводятся начиная с первого).
# - В шестой строке выведите все символы с нечетными индексами, то есть начиная со второго символа строки.
# - В седьмой строке выведите все символы в обратном порядке.
# - В восьмой строке выведите все символы строки через один в обратном порядке, начиная с последнего.
# - В девятой строке выведите длину данной строки.

# %%
string = "Карл у Клары украл кораллы."
print("Исходная строка: "+string)
print (string[2]) #вывод 3-го символа
print (string[-2]) #вывод предпоследнего символа
print (string[0:5]) #первые пять символов этой строки
print (string[0:-2]) #до предпоследнего символа
print (string[0::2]) #все символы с четными индексами (считая, что индексация начинается с 0, поэтому символы выводятся начиная с первого)
print (string[1::2]) #символы с нечетными индексами, то есть начиная со второго символа строки
print (string[::-1]) #все символы в обратном порядке
string_revrse = string[::-1]
print (string_revrse[0::2])#все символы строки через один в обратном порядке, начиная с последнего
print(len(string)) #длину данной строки
# Out:
# Исходная строка: Карл у Клары украл кораллы.
# р
# ы
# Карл
# Карл у Клары украл коралл
# Кр  лр ка оал.
# алуКаыурлкрлы
# .ылларок ларку ыралК у лраК
# .лао ак рл  рК
# 27

# %% [markdown]
# ## Задание 9

# %% [markdown]
# Дана строка. Если в этой строке буква f встречается только один раз, выведите её индекс. Если она встречается два и более раз, выведите индекс её первого и последнего появления. Если буква f в данной строке не встречается, ничего не выводите.
#
# __При решении этой задачи не стоит использовать циклы.__

# %%
string = "Five hugdred bucks" #1 символ f
#string = "lwbnfouewcmsleh wudfdbqvGovernment" #2 f
#string = "shni shnai shnappi, shnappi shnappi shnap" #0 f
string = string.lower()
f_count = string.count("f")
if f_count == 1 :
    print(string.find(("f")))
elif f_count >= 2:
    print(string.find(("f")))
    reversed_string = string[::-1]
    print(reversed_string.find("f"))

# %% [markdown]
# ## Задание 10

# %% [markdown]
# Пользователь (или несколько пользователей за одним компьютером) вводит слова. Начиная
# со второго введённого слова, программа проверяет, совпадает ли первая буква
# свежевведённого слова с последней буквой предыдущего. Если да, то программа работает
# дальше (считывает очередное слово). Если нет — выводит последнее на этот момент
# введённое слово и завершает работу.

# %%
word = input("Введите слово ")
while True:
    old_word = word
    word = input("Введите новое слово ")
    if old_word[-1] != word[0]:
        print(word)
        break
# Out:
# knk

# %% [markdown]
# ## Задание 11

# %% [markdown]
# Выведите слово так, как будто ему что-то мешает произноситься. Каждую букву нужно
# вывести столько раз, каков ее номер в строке.

# %%
word = input("word")
result = ""
for i, char in enumerate(word):
    result += char * (i + 1)
print(result)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 word = input("word")
#       2 result = ""
#       3 for i, char in enumerate(word):
#
# File c:\Users\ZemelyaD\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File c:\Users\ZemelyaD\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
# ...

# %% [markdown]
# ## Задание 12

# %% [markdown]
# Изобразите извилистый спуск улитки по стене по заданной траектории.
# Вводится одна строка. Начальный символ этой строки — символ рисования пути улитки.
# Далее следует последовательность символов “<”, “>” и “V”, которые означают движение
# улитки, соответственно, влево, вправо и вниз.
# Гарантируется, что по любой горизонтали движение происходит только в одну сторону
# (иными словами, между идущими в любом порядке “<” и “>” всегда есть хотя бы один “V”)
# и что путь не пройдёт левее начального положения.
# Выводятся несколько строк, состоящих из символов рисования пути и пробелов. Верхний
# левый угол соответствует начальному положению улитки. Каждый последующий символ
# входной строки означает, что нужно дорисовать символ рисования пути левее, правее или
# ниже предыдущего. Пробелы используются для отступов.

# %%
s = input("Введите путь (<, >, V)")
start_char = s[0]
moves = s[1:]

grid = [[start_char]]
row = 0
col = 0

for move in moves:
  if move == '<':
    col -= 1
    if col < 0:
      print("Ошибка: Нельзя двигаться левее начальной позиции.")
      exit()
    
    if row >= len(grid):
          grid.append([' ' for _ in range(len(grid[0]))]) 
    if col >= len(grid[row]):
          for r in grid:
              r.extend([' ' for _ in range(col - len(r) + 1)])
    if col < 0:
        print("Ошибка: Нельзя двигаться левее начальной позиции")
        exit()
    
    grid[row][col] = start_char
    
  elif move == '>':
    col += 1
    if row >= len(grid):
          grid.append([' ' for _ in range(len(grid[0]))])
    if col >= len(grid[row]):
          for r in grid:
              r.extend([' ' for _ in range(col - len(r) + 1)])      
    grid[row][col] = start_char

  elif move == 'V':
    row += 1
    if row >= len(grid):
      grid.append([' ' for _ in range(len(grid[0]))])

    if col >= len(grid[row]):
      for r in grid:
          r.extend([' ' for _ in range(col - len(r) + 1)])      
    grid[row][col] = start_char

for r in grid:
  print("".join(r))
# Out:
# ........
#        .
#        .
#        .
#        .
#      ...
#      .
#      .
#      .
#      ......
#           .
#          ..

# %% [markdown]
# ## Задание 13

# %% [markdown]
# Дан список чисел. Выведите все элементы списка, которые больше предыдущего элемента.

# %%
string = "9447234923742342348723648723"
result = ""  

for i in range(1, len(string)):
    if string[i] > string[i-1]:
        result = result + string[i] + " "  

print(result)
# Out:
# 7 3 4 9 3 7 3 4 3 4 8 3 6 8 3

# %% [markdown]
# ## Задание 14

# %% [markdown]
# Дан список чисел. Выведите все элементы списка, которые больше предыдущего элемента.

# %%
string = [5, 4, 8, 2, 9]
for i in range(1, len(string)):
    if string[i] > string[i - 1]:
        print(string[i])
# Out:
# 8
# 9

# %% [markdown]
# ## Задание 15

# %% [markdown]
# Напишите программу, которая составляет новое предложение по номерам слов из исходной
# строки. Предложение должно начинаться с большой буквы. Гарантируется, что в исходной
# строке только одна заглавная буква (в начале предложения).
# Нумерация слов начинается с единицы.

# %%
def create_sentence_from_words(sentence, word_numbers):
    words = sentence.split()
    new_sentence = ' '.join([words[i-1] for i in word_numbers])
    new_sentence = new_sentence.capitalize()
    return new_sentence

input_sentence = "Двигалась Александра по проезжей части и употребляла хлебобулочное изделие"
word_numbers = [2, 4, 6]  # Номера слов, которые нужно использовать

result = create_sentence_from_words(input_sentence, word_numbers)
print(result)
# Out:
# Александра проезжей и

# %% [markdown]
# ## Задание 16

# %% [markdown]
# Дан список чисел. Определите сколько в нем встречается различных чисел.

# %%
string = input()
unique = len(set(string))
print(unique)
# Out:
# 4

# %% [markdown]
# ## Задание 17

# %% [markdown]
# Даны два списка чисел. Посчитайте сколько чисел содержится одновременно как в первом списке, так и во втором.

# %%
string1 = input("Первый список")
string2 = input("Второй список")
unique = set(string1) & set(string2)
print(len(unique))
# Out:
# 1

# %% [markdown]
# ## Задание 18
# Дан текст: в первой строке записано число строк, далее идут сами строки. Определите, сколько различных слов содержится в этом тексте.
#
# Словом считается последовательность непробельных символов идущих подряд, слова разделены одним или большим числом пробелов или символами конца строки.

# %%
text = """5
Это первая строка
Вторая это строка
А это третья"""

lines = text.splitlines()
words = set()  
for line in lines[1:]: 
    for word in line.split():
        words.add(word)
print(len(words))
# Out:
# 7

# %% [markdown]
# ## Задание 19
# В единственной строке записан текст. Для каждого слова из данного текста подсчитайте, сколько раз оно встречалось в этом тексте ранее.
#
# Словом считается последовательность непробельных символов идущих подряд, слова разделены одним или большим числом пробелов или символами конца строки.

# %%
text = "добрый вечер добрый бобр"
words = text.lower().split()
counts = {}

for word in words:
    if word in counts:
        counts[word] += 1
    else:
        counts[word] = 1

sorted_counts = sorted(counts.items(), key=lambda item: item[1])

for word, count in sorted_counts:
    print(f'"{word}": {count}')
# Out:
# "вечер": 1
# "бобр": 1
# "добрый": 2

# %% [markdown]
# ## Задание 20
# Вам дан словарь, состоящий из пар слов. Каждое слово является синонимом к парному ему слову. Все слова в словаре различны.
# Для слова из словаря, записанного в последней строке, определите его синоним.
#
# Входные данные:
#
# 3
# Hello Hi
# Bye Goodbye
# List Array
# Goodbye
#
# Правильный ответ:
#
# Bye

# %%
synonym_list = [
    ("Hello", "Hi"),
    ("Bye", "Goodbye"),
    ("big", "large"),
    ("List", "Array"),
]

synonyms = {}
for word1, word2 in synonym_list:
    synonyms[word1] = word2
    synonyms[word2] = word1

print(synonyms["Hello"])
# Out:
# Hi

# %% [markdown]
# ## Задание 21
# Как известно, в США президент выбирается не прямым голосованием, а путем двухуровневого голосования. Сначала проводятся выборы в каждом штате и определяется победитель выборов в данном штате. Затем проводятся государственные выборы: на этих выборах каждый штат имеет определенное число голосов — число выборщиков от этого штата. На практике, все выборщики от штата голосуют в соответствии с результатами голосования внутри штата, то есть на заключительной стадии выборов в голосовании участвуют штаты, имеющие различное число голосов.
#
# В первой строке дано количество записей. Далее, каждая запись содержит фамилию кандидата и число голосов, отданных за него в одном из штатов. Подведите итоги выборов: для каждого из участника голосования определите число отданных за него голосов. Участников нужно выводить в алфавитном порядке.

# %%
votes_data = """McCain 10
McCain 2
Obama 9
Obama 8
McCain 1"""

votes_list = votes_data.strip().split('\n')
votes = {}

for vote in votes_list:
    name, count = vote.split()
    count = int(count)
    if name in votes:
        votes[name] += count
    else:
        votes[name] = count

sorted_votes = sorted(votes.items())

for name, count in sorted_votes:
    print(name, count)
# Out:
# McCain 13
# Obama 17

# %% [markdown]
# ## Задание 23
# Напишите программу для построения горизонтальных столбчатых диаграмм с помощью символа звездочки. Выводя строку, не используйте для этого цикл.

# %%
input_line = input()
numbers = list(map(int, input_line.split()))

result = ""
for number in numbers:
  result += "*" * number + "\n"

print(result)
# Out:
# *
# *****
# ***
# *

# %% [markdown]
# ## Задание 23
# Палиндром — это строка (или слово), которая читается одинаково в обоих направлениях, например, «12321» или известный пример Афанасия Фета «А роза упала на лапу Азора».
#
# Напишите функцию palindrome(s), которая принимает в качестве параметра строку и определяет, является ли она палиндромом. Функция должна возвращать строку «Палиндром» или «Не палиндром» соответственно.

# %%
def palindrome(s):
    processed_string = ''.join(c.lower() for c in s if c.isalnum())  
    return "Палиндром" if processed_string == processed_string[::-1] else "Не палиндром"


print(palindrome(input("Введите строку для проверки на палиндром")))
# Out:
# Палиндром
